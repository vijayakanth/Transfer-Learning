# %%
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import tensorflow as tf
import keras
import glob
import cv2
import os

#TRAINGING SET:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def getImages(no_of_classes=10):
    pest_images = []
    labels = []
    i = 0   
    for pest_image_path in glob.glob("/content/drive/MyDrive/ColabNotebooks/PestImages/pestRGB_256_256/*"):
        insect_label = pest_image_path.split("/")[-1]
        if no_of_classes == i:
            break
        for image_path in glob.glob(os.path.join(pest_image_path, "*.jpg")):
            image = cv2.imread(image_path, cv2.IMREAD_COLOR)
            image = cv2.imread(image_path)
            image = cv2.resize(image, (224, 224),interpolation = cv2.INTER_CUBIC) 
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            pest_images.append(image)
            labels.append(insect_label)
        i = i + 1

    pest_images = np.array(pest_images)
    labels = np.array(labels)
    label_to_id_dict = {v: i for i, v in enumerate(np.unique(labels))}
    id_to_label_dict = {v: k for k, v in label_to_id_dict.items()}
  
    label_ids = np.array([label_to_id_dict[x] for x in labels])
    pest_images.shape, label_ids.shape, labels.shape
    
    print ("Total Images : " +  str(pest_images.shape[0]))
    # print ("Total Labels : " +  str(label_ids))     
    return pest_images, label_ids

# %%
pests, labels = getImages(no_of_classes=10)
# Out:
# Total Images : 500

# %%
#data augmentation
def Augmentation(X_train,X_valid,X_test,Y_train,Y_valid,Y_test,batch_size,test_batchSize):
       
        #Augmentation ,we will use for training and not in validation and testing
        train_datagen= ImageDataGenerator(rescale=1./255,
                                          rotation_range=30,
                                          width_shift_range=0.2,
                                          height_shift_range=0.2,
                                          shear_range=0.2,
                                          zoom_range=0.2,
                                          horizontal_flip=True)
        
        valid_datagen = ImageDataGenerator(rescale=1. / 255)
        test_datagen = ImageDataGenerator(rescale=1. / 255)

        train_batch = train_datagen.flow(X_train,
                                         Y_train,                                         
                                         batch_size=batch_size,shuffle=True)              
                                        
        valid_batch = valid_datagen.flow(X_valid,
                                         Y_valid,
                                         batch_size=batch_size,shuffle=True)            

        test_batch = test_datagen.flow(X_test,
                                       Y_test,                                       
                                       batch_size=test_batchSize,shuffle=False)              
                                       
        return (train_batch,valid_batch,test_batch)

# %%
#SETTING UP VGG-16
def model(X_train,X_valid, X_test, Y_train, Y_valid, Y_test,Y, numClasses):
    from keras.layers import Dense, Dropout, Flatten    
    from keras.applications.vgg16 import VGG16
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import accuracy_score
    from keras.models import Sequential
    from keras.models import Model
     

    vgg16_model=VGG16(weights='imagenet',include_top=False, input_shape=(224,224,3))
    # don't train the existing weights
    # for layer in vgg16_model.layers:
    #         layer.trainable=False
    # I chose to train the top 3 inception blocks, i.e. I will freeze the first 15 layers and unfreeze the rest:
    for layer in vgg16_model.layers[:10]:
            layer.trainable=False
    for layer in vgg16_model.layers[10:]:
            layer.trainable=True
    
    x = vgg16_model.output   
    x = Dropout(0.3)(x) 
    x = Flatten()(x)
    # x = Dense(1024, activation='relu')(x)
    x = Dense(512, activation='relu')(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.3)(x)    
    x = Dense(numClasses,activation='softmax')(x)#create the new model
    model = Model(inputs=vgg16_model.input, outputs=x)
    # print(model.summary())

    from tensorflow.keras.optimizers import SGD
    # model.compile(optimizer=SGD(lr=0.0001), loss='categorical_crossentropy',metrics=['accuracy'])
    model.compile(optimizer=SGD(lr=0.0001), loss='categorical_crossentropy',metrics=['accuracy'])

    # opt = keras.optimizers.Adam(lr=0.0001)
    # model.compile(loss=keras.losses.categorical_crossentropy,
    #               optimizer=opt,
    #               metrics=['accuracy'])    

    batch_size = 25
    test_batchSize=1
    epochs = 50
    train_batch, valid_batch,test_batch = Augmentation(X_train,X_valid, X_test, Y_train, Y_valid, Y_test,batch_size,test_batchSize)
      
    model.fit(train_batch, 
              steps_per_epoch= X_train.shape[0]//batch_size,
              validation_data=valid_batch, 
              epochs=epochs,
              validation_steps=X_valid.shape[0]//batch_size, 
              verbose=2)

    test_accuracy=model.evaluate(test_batch,steps=len(test_batch))
    print('Testing Accuracy :',test_accuracy)
   
    return test_accuracy

# %%
from sklearn.model_selection  import train_test_split,KFold
numClasses=10
train,test,trLabels,teLabels=train_test_split(pests,labels,test_size=0.2, random_state=42)
print(train.shape,trLabels.shape,test.shape,teLabels.shape)
X_test = test
Y_test = teLabels    
Y=Y_test
Y_test = keras.utils.to_categorical(Y_test,numClasses)
def KFoldCV(Images, Labels, numClasses):
    # KFold Cross Validation approach
    kf = KFold(n_splits=8,shuffle=True,random_state=42)
    kf.split(Images)

    # Initialize the test accuracy array. The testing accuracy of each model will be added to this array
    test_accuracy_model = []
    Fold=1
    # Iterate over each train-test split
    for train_index, valid_index in kf.split(Images):
          # print('train_index: ', train_index)
          # print('valid_index: ', valid_index)
          print('Fold No:', Fold)
        # Split training:validation        
          X_train, X_valid = Images[train_index], Images[valid_index]
          Y_train, Y_valid = Labels[train_index], Labels[valid_index]         

        #One Hot Encode the Output
          Y_train = keras.utils.to_categorical(Y_train,numClasses)
          Y_valid = keras.utils.to_categorical(Y_valid,numClasses)         

        # Train the model
          print('Original Sizes:', X_train.shape,X_valid.shape, X_test.shape,Y_train.shape,Y_valid.shape,Y_test.shape)
          score=model(X_train, X_valid,X_test, Y_train, Y_valid, Y_test,Y,numClasses)
          test_accuracy_model.append(score[1]*100)
    
          Fold=Fold+1
    return (test_accuracy_model)
# Out:
# (400, 224, 224, 3) (400,) (100, 224, 224, 3) (100,)

# %% [markdown]
# #  8-Fold 10 Classes

# %%
import time
start_time= time.time()
accurary = KFoldCV(train,trLabels, 10)
end_time=time.time()
print(accurary)
print("%s: %.2f%%" % ("Average Accuracy: ",np.mean(accurary)))
print("%s: %.2f%%" % ("Standard Deviation: +/-", np.std(accurary)))
print("Total time taken {}".format(end_time-start_time))
# Out:
# Fold No: 1
# Original Sizes: (350, 224, 224, 3) (50, 224, 224, 3) (100, 224, 224, 3) (350, 10) (50, 10) (100, 10)
# Epoch 1/50
# 14/14 - 4s - loss: 2.6062 - accuracy: 0.1057 - val_loss: 2.2857 - val_accuracy: 0.2000
# Epoch 2/50
# 14/14 - 4s - loss: 2.4844 - accuracy: 0.1057 - val_loss: 2.2601 - val_accuracy: 0.2200
# Epoch 3/50
# 14/14 - 4s - loss: 2.4814 - accuracy: 0.1229 - val_loss: 2.2532 - val_accuracy: 0.1800
# Epoch 4/50
# 14/14 - 4s - loss: 2.4001 - accuracy: 0.1343 - val_loss: 2.2509 - val_accuracy: 0.1200
# Epoch 5/50
# 14/14 - 4s - loss: 2.3739 - accuracy: 0.1343 - val_loss: 2.2446 - val_accuracy: 0.1200
# Epoch 6/50
# 14/14 - 4s - loss: 2.3430 - accuracy: 0.1029 - val_loss: 2.2359 - val_accuracy: 0.1400
# Epoch 7/50
# 14/14 - 4s - loss: 2.3703 - accuracy: 0.1343 - val_loss: 2.2260 - val_accuracy: 0.2000
# Epoch 8/50
# 14/14 - 4s - loss: 2.3631 - accuracy: 0.1286 - val_loss: 2.2207 - val_accuracy: 0.2400
# Epoch 9/50
# 14/14 - 4s - loss: 2.3152 - accuracy: 0.1400 - val_loss: 2.2118 - val_accuracy: 0.2800
# Epoch 10/50
# 14/14 - 4s - loss: 2.3316 - accuracy: 0.1400 - val_loss: 2.2003 - val_accuracy: 0.3000
# Epoch 11/50
# 14/14 - 4s - loss: 2.2992 - accuracy: 0.1629 - val_loss: 2.1928 - val_accuracy: 0.2800
# Epoch 12/50
# 14/14 - 4s - loss: 2.3094 - accuracy: 0.1143 - val_loss: 2.1855 - val_accuracy: 0.3200
# Epoch 13/50
# 14/14 - 4s - loss: 2.2434 - accuracy: 0.1800 - val_loss: 2.1774 - val_accuracy: 0.3200
# Epoch 14/50
# 14/14 - 4s - loss: 2.3106 - accuracy: 0.1457 - val_loss: 2.1688 - val_accuracy: 0.3200
# Epoch 15/50
# 14/14 - 4s - loss: 2.2719 - accuracy: 0.1486 - val_loss: 2.1598 - val_accuracy: 0.3400
# Epoch 16/50
# 14/14 - 4s - loss: 2.2937 - accuracy: 0.1771 - val_loss: 2.1469 - val_accuracy: 0.3400
# Epoch 17/50
# 14/14 - 4s - loss: 2.2507 - accuracy: 0.1914 - val_loss: 2.1352 - val_accuracy: 0.3400
# Epoch 18/50
# 14/14 - 4s - loss: 2.2593 - accuracy: 0.1686 - val_loss: 2.1180 - val_accuracy: 0.3400
# Epoch 19/50
# 14/14 - 4s - loss: 2.2441 - accuracy: 0.1771 - val_loss: 2.1084 - val_accuracy: 0.3600
# Epoch 20/50
# 14/14 - 4s - loss: 2.2465 - accuracy: 0.1686 - val_loss: 2.0954 - val_accuracy: 0.3600
# Epoch 21/50
# 14/14 - 4s - loss: 2.2615 - accuracy: 0.1914 - val_loss: 2.0877 - val_accuracy: 0.4200
# Epoch 22/50
# 14/14 - 4s - loss: 2.1661 - accuracy: 0.2486 - val_loss: 2.0755 - val_accuracy: 0.3800
# Epoch 23/50
# 14/14 - 4s - loss: 2.2015 - accuracy: 0.1857 - val_loss: 2.0642 - val_accuracy: 0.4200
# Epoch 24/50
# 14/14 - 4s - loss: 2.1873 - accuracy: 0.2143 - val_loss: 2.0505 - val_accuracy: 0.4200
# Epoch 25/50
# 14/14 - 4s - loss: 2.1917 - accuracy: 0.1714 - val_loss: 2.0342 - val_accuracy: 0.4600
# Epoch 26/50
# 14/14 - 4s - loss: 2.1712 - accuracy: 0.2029 - val_loss: 2.0194 - val_accuracy: 0.5000
# Epoch 27/50
# 14/14 - 4s - loss: 2.1756 - accuracy: 0.1971 - val_loss: 2.0057 - val_accuracy: 0.5000
# Epoch 28/50
# 14/14 - 4s - loss: 2.1249 - accuracy: 0.2543 - val_loss: 1.9889 - val_accuracy: 0.5000
# Epoch 29/50
# 14/14 - 4s - loss: 2.1516 - accuracy: 0.2029 - val_loss: 1.9777 - val_accuracy: 0.5200
# Epoch 30/50
# 14/14 - 4s - loss: 2.1253 - accuracy: 0.2400 - val_loss: 1.9579 - val_accuracy: 0.6000
# Epoch 31/50
# 14/14 - 4s - loss: 2.1481 - accuracy: 0.2343 - val_loss: 1.9414 - val_accuracy: 0.6200
# Epoch 32/50
# 14/14 - 4s - loss: 2.1258 - accuracy: 0.2714 - val_loss: 1.9248 - val_accuracy: 0.6200
# Epoch 33/50
# 14/14 - 4s - loss: 2.1267 - accuracy: 0.2114 - val_loss: 1.9124 - val_accuracy: 0.6200
# Epoch 34/50
# 14/14 - 4s - loss: 2.1208 - accuracy: 0.2286 - val_loss: 1.8950 - val_accuracy: 0.6400
# Epoch 35/50
# 14/14 - 4s - loss: 2.0970 - accuracy: 0.2886 - val_loss: 1.8822 - val_accuracy: 0.6400
# Epoch 36/50
# 14/14 - 4s - loss: 2.1034 - accuracy: 0.2686 - val_loss: 1.8641 - val_accuracy: 0.6600
# Epoch 37/50
# 14/14 - 4s - loss: 2.1015 - accuracy: 0.2200 - val_loss: 1.8454 - val_accuracy: 0.6400
# Epoch 38/50
# 14/14 - 4s - loss: 2.0838 - accuracy: 0.2771 - val_loss: 1.8297 - val_accuracy: 0.6800
# Epoch 39/50
# 14/14 - 4s - loss: 2.0573 - accuracy: 0.2829 - val_loss: 1.8137 - val_accuracy: 0.7000
# Epoch 40/50
# 14/14 - 4s - loss: 2.0331 - accuracy: 0.3000 - val_loss: 1.8003 - val_accuracy: 0.7000
# Epoch 41/50
# 14/14 - 4s - loss: 2.0451 - accuracy: 0.3000 - val_loss: 1.7821 - val_accuracy: 0.6800
# Epoch 42/50
# 14/14 - 4s - loss: 2.0183 - accuracy: 0.2971 - val_loss: 1.7584 - val_accuracy: 0.6800
# Epoch 43/50
# 14/14 - 4s - loss: 1.9994 - accuracy: 0.2857 - val_loss: 1.7315 - val_accuracy: 0.7200
# Epoch 44/50
# 14/14 - 4s - loss: 1.9739 - accuracy: 0.3371 - val_loss: 1.7103 - val_accuracy: 0.7800
# Epoch 45/50
# 14/14 - 4s - loss: 1.9330 - accuracy: 0.3400 - val_loss: 1.6851 - val_accuracy: 0.7800
# Epoch 46/50
# 14/14 - 4s - loss: 1.9505 - accuracy: 0.3200 - val_loss: 1.6647 - val_accuracy: 0.7200
# Epoch 47/50
# 14/14 - 4s - loss: 1.9234 - accuracy: 0.3486 - val_loss: 1.6447 - val_accuracy: 0.7400
# Epoch 48/50
# 14/14 - 4s - loss: 1.9434 - accuracy: 0.3486 - val_loss: 1.6236 - val_accuracy: 0.7400
# Epoch 49/50
# 14/14 - 4s - loss: 1.9102 - accuracy: 0.3343 - val_loss: 1.5996 - val_accuracy: 0.7600
# Epoch 50/50
# 14/14 - 4s - loss: 1.8921 - accuracy: 0.3914 - val_loss: 1.5766 - val_accuracy: 0.7600
# 100/100 [==============================] - 1s 7ms/step - loss: 1.6615 - accuracy: 0.6400
# Testing Accuracy : [1.661530613899231, 0.6399999856948853]
# Fold No: 2
# Original Sizes: (350, 224, 224, 3) (50, 224, 224, 3) (100, 224, 224, 3) (350, 10) (50, 10) (100, 10)
# Epoch 1/50
# 14/14 - 4s - loss: 2.6104 - accuracy: 0.1000 - val_loss: 2.4708 - val_accuracy: 0.0400
# Epoch 2/50
# 14/14 - 4s - loss: 2.5430 - accuracy: 0.1086 - val_loss: 2.4022 - val_accuracy: 0.0400
# Epoch 3/50
# 14/14 - 4s - loss: 2.4199 - accuracy: 0.1257 - val_loss: 2.3691 - val_accuracy: 0.0400
# Epoch 4/50
# 14/14 - 4s - loss: 2.4370 - accuracy: 0.0943 - val_loss: 2.3477 - val_accuracy: 0.0600
# Epoch 5/50
# 14/14 - 4s - loss: 2.4122 - accuracy: 0.0971 - val_loss: 2.3307 - val_accuracy: 0.0600
# Epoch 6/50
# 14/14 - 4s - loss: 2.4511 - accuracy: 0.0800 - val_loss: 2.3144 - val_accuracy: 0.0600
# Epoch 7/50
# 14/14 - 4s - loss: 2.4155 - accuracy: 0.0829 - val_loss: 2.2934 - val_accuracy: 0.0800
# Epoch 8/50
# 14/14 - 4s - loss: 2.3782 - accuracy: 0.0914 - val_loss: 2.2845 - val_accuracy: 0.1000
# Epoch 9/50
# 14/14 - 4s - loss: 2.3572 - accuracy: 0.1343 - val_loss: 2.2701 - val_accuracy: 0.1200
# Epoch 10/50
# 14/14 - 4s - loss: 2.3406 - accuracy: 0.1371 - val_loss: 2.2576 - val_accuracy: 0.1400
# Epoch 11/50
# 14/14 - 4s - loss: 2.3253 - accuracy: 0.1171 - val_loss: 2.2465 - val_accuracy: 0.1600
# Epoch 12/50
# 14/14 - 4s - loss: 2.3403 - accuracy: 0.1314 - val_loss: 2.2396 - val_accuracy: 0.1600
# Epoch 13/50
# 14/14 - 4s - loss: 2.2942 - accuracy: 0.1457 - val_loss: 2.2287 - val_accuracy: 0.1600
# Epoch 14/50
# 14/14 - 4s - loss: 2.2854 - accuracy: 0.1629 - val_loss: 2.2172 - val_accuracy: 0.1800
# Epoch 15/50
# 14/14 - 4s - loss: 2.2830 - accuracy: 0.1571 - val_loss: 2.2048 - val_accuracy: 0.1800
# Epoch 16/50
# 14/14 - 4s - loss: 2.2735 - accuracy: 0.1657 - val_loss: 2.1959 - val_accuracy: 0.2000
# Epoch 17/50
# 14/14 - 4s - loss: 2.2834 - accuracy: 0.1457 - val_loss: 2.1805 - val_accuracy: 0.2200
# Epoch 18/50
# 14/14 - 4s - loss: 2.2611 - accuracy: 0.1543 - val_loss: 2.1684 - val_accuracy: 0.2200
# Epoch 19/50
# 14/14 - 4s - loss: 2.2169 - accuracy: 0.2143 - val_loss: 2.1575 - val_accuracy: 0.2400
# Epoch 20/50
# 14/14 - 4s - loss: 2.2446 - accuracy: 0.1800 - val_loss: 2.1485 - val_accuracy: 0.2600
# Epoch 21/50
# 14/14 - 4s - loss: 2.2247 - accuracy: 0.1657 - val_loss: 2.1353 - val_accuracy: 0.2800
# Epoch 22/50
# 14/14 - 4s - loss: 2.2353 - accuracy: 0.1971 - val_loss: 2.1273 - val_accuracy: 0.2600
# Epoch 23/50
# 14/14 - 4s - loss: 2.2172 - accuracy: 0.2086 - val_loss: 2.1173 - val_accuracy: 0.2800
# Epoch 24/50
# 14/14 - 4s - loss: 2.1849 - accuracy: 0.2114 - val_loss: 2.1032 - val_accuracy: 0.3200
# Epoch 25/50
# 14/14 - 4s - loss: 2.1907 - accuracy: 0.2200 - val_loss: 2.0930 - val_accuracy: 0.3200
# Epoch 26/50
# 14/14 - 4s - loss: 2.1784 - accuracy: 0.2286 - val_loss: 2.0817 - val_accuracy: 0.3600
# Epoch 27/50
# 14/14 - 4s - loss: 2.1926 - accuracy: 0.2086 - val_loss: 2.0698 - val_accuracy: 0.3600
# Epoch 28/50
# 14/14 - 4s - loss: 2.2036 - accuracy: 0.2114 - val_loss: 2.0655 - val_accuracy: 0.3600
# Epoch 29/50
# 14/14 - 4s - loss: 2.1712 - accuracy: 0.2171 - val_loss: 2.0527 - val_accuracy: 0.3800
# Epoch 30/50
# 14/14 - 4s - loss: 2.1378 - accuracy: 0.2114 - val_loss: 2.0376 - val_accuracy: 0.4000
# Epoch 31/50
# 14/14 - 4s - loss: 2.0854 - accuracy: 0.2314 - val_loss: 2.0251 - val_accuracy: 0.4000
# Epoch 32/50
# 14/14 - 4s - loss: 2.1401 - accuracy: 0.2200 - val_loss: 2.0124 - val_accuracy: 0.3800
# Epoch 33/50
# 14/14 - 4s - loss: 2.0616 - accuracy: 0.2657 - val_loss: 1.9967 - val_accuracy: 0.4000
# Epoch 34/50
# 14/14 - 4s - loss: 2.0880 - accuracy: 0.2429 - val_loss: 1.9776 - val_accuracy: 0.4400
# Epoch 35/50
# 14/14 - 4s - loss: 2.0891 - accuracy: 0.2371 - val_loss: 1.9689 - val_accuracy: 0.4600
# Epoch 36/50
# 14/14 - 4s - loss: 2.1052 - accuracy: 0.2514 - val_loss: 1.9497 - val_accuracy: 0.4600
# Epoch 37/50
# 14/14 - 4s - loss: 2.0639 - accuracy: 0.2600 - val_loss: 1.9333 - val_accuracy: 0.4800
# Epoch 38/50
# 14/14 - 4s - loss: 2.0355 - accuracy: 0.3000 - val_loss: 1.9189 - val_accuracy: 0.5200
# Epoch 39/50
# 14/14 - 4s - loss: 2.0314 - accuracy: 0.2800 - val_loss: 1.8972 - val_accuracy: 0.5200
# Epoch 40/50
# 14/14 - 4s - loss: 1.9504 - accuracy: 0.3429 - val_loss: 1.8717 - val_accuracy: 0.5200
# Epoch 41/50
# 14/14 - 4s - loss: 2.0095 - accuracy: 0.2886 - val_loss: 1.8543 - val_accuracy: 0.5400
# Epoch 42/50
# 14/14 - 4s - loss: 1.9681 - accuracy: 0.3200 - val_loss: 1.8357 - val_accuracy: 0.5800
# Epoch 43/50
# 14/14 - 4s - loss: 1.9768 - accuracy: 0.2886 - val_loss: 1.8124 - val_accuracy: 0.6000
# Epoch 44/50
# 14/14 - 4s - loss: 1.9691 - accuracy: 0.3429 - val_loss: 1.7956 - val_accuracy: 0.5800
# Epoch 45/50
# 14/14 - 4s - loss: 1.9581 - accuracy: 0.3229 - val_loss: 1.7712 - val_accuracy: 0.5800
# Epoch 46/50
# 14/14 - 4s - loss: 1.9559 - accuracy: 0.3257 - val_loss: 1.7483 - val_accuracy: 0.6000
# Epoch 47/50
# 14/14 - 4s - loss: 1.9496 - accuracy: 0.3629 - val_loss: 1.7301 - val_accuracy: 0.5800
# Epoch 48/50
# 14/14 - 4s - loss: 1.9291 - accuracy: 0.3200 - val_loss: 1.7078 - val_accuracy: 0.6000
# Epoch 49/50
# 14/14 - 4s - loss: 1.8498 - accuracy: 0.3914 - val_loss: 1.6892 - val_accuracy: 0.6000
# Epoch 50/50
# 14/14 - 4s - loss: 1.8491 - accuracy: 0.3743 - val_loss: 1.6626 - val_accuracy: 0.6400
# 100/100 [==============================] - 1s 7ms/step - loss: 1.6448 - accuracy: 0.6200
# Testing Accuracy : [1.6447967290878296, 0.6200000047683716]
# Fold No: 3
# Original Sizes: (350, 224, 224, 3) (50, 224, 224, 3) (100, 224, 224, 3) (350, 10) (50, 10) (100, 10)
# Epoch 1/50
# 14/14 - 4s - loss: 2.5813 - accuracy: 0.1171 - val_loss: 2.3607 - val_accuracy: 0.0800
# Epoch 2/50
# 14/14 - 4s - loss: 2.5735 - accuracy: 0.0971 - val_loss: 2.3507 - val_accuracy: 0.1200
# Epoch 3/50
# 14/14 - 4s - loss: 2.4648 - accuracy: 0.1143 - val_loss: 2.3412 - val_accuracy: 0.0800
# Epoch 4/50
# 14/14 - 4s - loss: 2.4581 - accuracy: 0.1114 - val_loss: 2.3335 - val_accuracy: 0.0800
# Epoch 5/50
# 14/14 - 4s - loss: 2.4114 - accuracy: 0.1114 - val_loss: 2.3180 - val_accuracy: 0.1000
# Epoch 6/50
# 14/14 - 4s - loss: 2.3895 - accuracy: 0.1114 - val_loss: 2.3113 - val_accuracy: 0.0800
# Epoch 7/50
# 14/14 - 4s - loss: 2.3694 - accuracy: 0.1400 - val_loss: 2.2926 - val_accuracy: 0.1200
# Epoch 8/50
# 14/14 - 4s - loss: 2.3466 - accuracy: 0.1371 - val_loss: 2.2789 - val_accuracy: 0.1600
# Epoch 9/50
# 14/14 - 4s - loss: 2.3972 - accuracy: 0.1257 - val_loss: 2.2701 - val_accuracy: 0.2000
# Epoch 10/50
# 14/14 - 4s - loss: 2.3118 - accuracy: 0.1629 - val_loss: 2.2532 - val_accuracy: 0.2000
# Epoch 11/50
# 14/14 - 4s - loss: 2.2411 - accuracy: 0.1657 - val_loss: 2.2508 - val_accuracy: 0.2000
# Epoch 12/50
# 14/14 - 4s - loss: 2.3116 - accuracy: 0.1371 - val_loss: 2.2381 - val_accuracy: 0.2000
# Epoch 13/50
# 14/14 - 4s - loss: 2.3473 - accuracy: 0.1143 - val_loss: 2.2239 - val_accuracy: 0.2000
# Epoch 14/50
# 14/14 - 4s - loss: 2.2807 - accuracy: 0.1743 - val_loss: 2.2164 - val_accuracy: 0.2400
# Epoch 15/50
# 14/14 - 4s - loss: 2.2482 - accuracy: 0.1657 - val_loss: 2.1995 - val_accuracy: 0.2200
# Epoch 16/50
# 14/14 - 4s - loss: 2.2229 - accuracy: 0.1971 - val_loss: 2.1856 - val_accuracy: 0.2400
# Epoch 17/50
# 14/14 - 4s - loss: 2.2201 - accuracy: 0.2029 - val_loss: 2.1642 - val_accuracy: 0.2400
# Epoch 18/50
# 14/14 - 4s - loss: 2.2246 - accuracy: 0.2029 - val_loss: 2.1564 - val_accuracy: 0.2600
# Epoch 19/50
# 14/14 - 4s - loss: 2.2395 - accuracy: 0.1686 - val_loss: 2.1367 - val_accuracy: 0.2800
# Epoch 20/50
# 14/14 - 4s - loss: 2.2002 - accuracy: 0.2086 - val_loss: 2.1218 - val_accuracy: 0.2800
# Epoch 21/50
# 14/14 - 4s - loss: 2.1813 - accuracy: 0.2114 - val_loss: 2.1163 - val_accuracy: 0.2800
# Epoch 22/50
# 14/14 - 4s - loss: 2.2100 - accuracy: 0.1971 - val_loss: 2.1037 - val_accuracy: 0.2800
# Epoch 23/50
# 14/14 - 4s - loss: 2.1896 - accuracy: 0.2229 - val_loss: 2.0904 - val_accuracy: 0.3200
# Epoch 24/50
# 14/14 - 4s - loss: 2.1577 - accuracy: 0.2257 - val_loss: 2.0768 - val_accuracy: 0.3400
# Epoch 25/50
# 14/14 - 4s - loss: 2.1831 - accuracy: 0.2086 - val_loss: 2.0588 - val_accuracy: 0.3600
# Epoch 26/50
# 14/14 - 4s - loss: 2.1649 - accuracy: 0.2371 - val_loss: 2.0406 - val_accuracy: 0.3800
# Epoch 27/50
# 14/14 - 4s - loss: 2.1897 - accuracy: 0.2257 - val_loss: 2.0256 - val_accuracy: 0.4200
# Epoch 28/50
# 14/14 - 4s - loss: 2.1215 - accuracy: 0.2314 - val_loss: 2.0129 - val_accuracy: 0.4000
# Epoch 29/50
# 14/14 - 4s - loss: 2.0614 - accuracy: 0.2943 - val_loss: 1.9983 - val_accuracy: 0.4200
# Epoch 30/50
# 14/14 - 4s - loss: 2.0753 - accuracy: 0.2486 - val_loss: 1.9765 - val_accuracy: 0.4400
# Epoch 31/50
# 14/14 - 4s - loss: 2.0910 - accuracy: 0.2771 - val_loss: 1.9607 - val_accuracy: 0.4400
# Epoch 32/50
# 14/14 - 4s - loss: 2.0332 - accuracy: 0.2800 - val_loss: 1.9467 - val_accuracy: 0.4800
# Epoch 33/50
# 14/14 - 4s - loss: 2.1114 - accuracy: 0.2400 - val_loss: 1.9386 - val_accuracy: 0.4600
# Epoch 34/50
# 14/14 - 4s - loss: 2.0771 - accuracy: 0.2629 - val_loss: 1.9181 - val_accuracy: 0.4600
# Epoch 35/50
# 14/14 - 4s - loss: 2.0976 - accuracy: 0.2486 - val_loss: 1.9065 - val_accuracy: 0.4600
# Epoch 36/50
# 14/14 - 4s - loss: 2.0283 - accuracy: 0.3029 - val_loss: 1.8786 - val_accuracy: 0.4800
# Epoch 37/50
# 14/14 - 4s - loss: 2.0103 - accuracy: 0.3229 - val_loss: 1.8639 - val_accuracy: 0.4600
# Epoch 38/50
# 14/14 - 4s - loss: 1.9723 - accuracy: 0.3257 - val_loss: 1.8399 - val_accuracy: 0.4600
# Epoch 39/50
# 14/14 - 4s - loss: 1.9311 - accuracy: 0.3514 - val_loss: 1.8172 - val_accuracy: 0.4600
# Epoch 40/50
# 14/14 - 4s - loss: 1.9819 - accuracy: 0.3143 - val_loss: 1.7920 - val_accuracy: 0.4600
# Epoch 41/50
# 14/14 - 4s - loss: 1.9491 - accuracy: 0.3429 - val_loss: 1.7690 - val_accuracy: 0.4600
# Epoch 42/50
# 14/14 - 4s - loss: 1.9266 - accuracy: 0.3543 - val_loss: 1.7584 - val_accuracy: 0.5000
# Epoch 43/50
# 14/14 - 4s - loss: 1.9095 - accuracy: 0.3714 - val_loss: 1.7291 - val_accuracy: 0.5000
# Epoch 44/50
# 14/14 - 4s - loss: 1.8843 - accuracy: 0.3829 - val_loss: 1.7099 - val_accuracy: 0.5600
# Epoch 45/50
# 14/14 - 4s - loss: 1.8965 - accuracy: 0.3800 - val_loss: 1.6847 - val_accuracy: 0.5400
# Epoch 46/50
# 14/14 - 4s - loss: 1.8342 - accuracy: 0.3829 - val_loss: 1.6580 - val_accuracy: 0.6000
# Epoch 47/50
# 14/14 - 4s - loss: 1.8075 - accuracy: 0.3829 - val_loss: 1.6316 - val_accuracy: 0.6200
# Epoch 48/50
# 14/14 - 4s - loss: 1.7951 - accuracy: 0.4200 - val_loss: 1.6097 - val_accuracy: 0.5800
# Epoch 49/50
# 14/14 - 4s - loss: 1.7271 - accuracy: 0.4600 - val_loss: 1.5838 - val_accuracy: 0.5800
# Epoch 50/50
# 14/14 - 4s - loss: 1.7424 - accuracy: 0.4029 - val_loss: 1.5633 - val_accuracy: 0.5800
# 100/100 [==============================] - 1s 7ms/step - loss: 1.5234 - accuracy: 0.6300
# Testing Accuracy : [1.5233964920043945, 0.6299999952316284]
# Fold No: 4
# Original Sizes: (350, 224, 224, 3) (50, 224, 224, 3) (100, 224, 224, 3) (350, 10) (50, 10) (100, 10)
# Epoch 1/50
# 14/14 - 5s - loss: 2.6416 - accuracy: 0.1286 - val_loss: 2.3091 - val_accuracy: 0.1400
# Epoch 2/50
# 14/14 - 4s - loss: 2.5534 - accuracy: 0.0857 - val_loss: 2.2681 - val_accuracy: 0.1800
# Epoch 3/50
# 14/14 - 4s - loss: 2.5052 - accuracy: 0.1000 - val_loss: 2.2569 - val_accuracy: 0.2200
# Epoch 4/50
# 14/14 - 4s - loss: 2.4181 - accuracy: 0.1314 - val_loss: 2.2492 - val_accuracy: 0.2000
# Epoch 5/50
# 14/14 - 4s - loss: 2.4144 - accuracy: 0.1057 - val_loss: 2.2379 - val_accuracy: 0.1800
# Epoch 6/50
# 14/14 - 4s - loss: 2.4120 - accuracy: 0.1343 - val_loss: 2.2295 - val_accuracy: 0.1800
# Epoch 7/50
# 14/14 - 4s - loss: 2.3588 - accuracy: 0.1629 - val_loss: 2.2257 - val_accuracy: 0.2000
# Epoch 8/50
# 14/14 - 4s - loss: 2.3638 - accuracy: 0.1229 - val_loss: 2.2211 - val_accuracy: 0.1800
# Epoch 9/50
# 14/14 - 4s - loss: 2.3556 - accuracy: 0.1571 - val_loss: 2.2137 - val_accuracy: 0.1800
# Epoch 10/50
# 14/14 - 4s - loss: 2.3250 - accuracy: 0.1486 - val_loss: 2.1920 - val_accuracy: 0.2000
# Epoch 11/50
# 14/14 - 4s - loss: 2.3676 - accuracy: 0.1286 - val_loss: 2.1862 - val_accuracy: 0.2000
# Epoch 12/50
# 14/14 - 4s - loss: 2.2724 - accuracy: 0.1800 - val_loss: 2.1717 - val_accuracy: 0.2000
# Epoch 13/50
# 14/14 - 4s - loss: 2.2778 - accuracy: 0.1600 - val_loss: 2.1612 - val_accuracy: 0.2000
# Epoch 14/50
# 14/14 - 4s - loss: 2.3062 - accuracy: 0.1571 - val_loss: 2.1510 - val_accuracy: 0.2000
# Epoch 15/50
# 14/14 - 4s - loss: 2.2791 - accuracy: 0.1714 - val_loss: 2.1329 - val_accuracy: 0.2400
# Epoch 16/50
# 14/14 - 4s - loss: 2.2998 - accuracy: 0.1343 - val_loss: 2.1258 - val_accuracy: 0.2400
# Epoch 17/50
# 14/14 - 4s - loss: 2.2730 - accuracy: 0.1743 - val_loss: 2.1175 - val_accuracy: 0.2400
# Epoch 18/50
# 14/14 - 4s - loss: 2.2711 - accuracy: 0.1714 - val_loss: 2.1090 - val_accuracy: 0.2400
# Epoch 19/50
# 14/14 - 4s - loss: 2.2532 - accuracy: 0.1657 - val_loss: 2.0971 - val_accuracy: 0.2800
# Epoch 20/50
# 14/14 - 4s - loss: 2.2523 - accuracy: 0.1857 - val_loss: 2.0883 - val_accuracy: 0.2800
# Epoch 21/50
# 14/14 - 4s - loss: 2.2268 - accuracy: 0.1857 - val_loss: 2.0740 - val_accuracy: 0.3000
# Epoch 22/50
# 14/14 - 4s - loss: 2.2124 - accuracy: 0.1857 - val_loss: 2.0616 - val_accuracy: 0.3000
# Epoch 23/50
# 14/14 - 4s - loss: 2.2265 - accuracy: 0.1743 - val_loss: 2.0519 - val_accuracy: 0.3200
# Epoch 24/50
# 14/14 - 4s - loss: 2.1691 - accuracy: 0.2229 - val_loss: 2.0475 - val_accuracy: 0.3000
# Epoch 25/50
# 14/14 - 4s - loss: 2.2013 - accuracy: 0.1886 - val_loss: 2.0383 - val_accuracy: 0.3000
# Epoch 26/50
# 14/14 - 4s - loss: 2.1699 - accuracy: 0.2229 - val_loss: 2.0252 - val_accuracy: 0.3200
# Epoch 27/50
# 14/14 - 4s - loss: 2.1425 - accuracy: 0.2257 - val_loss: 2.0086 - val_accuracy: 0.3400
# Epoch 28/50
# 14/14 - 4s - loss: 2.1451 - accuracy: 0.2314 - val_loss: 1.9953 - val_accuracy: 0.3400
# Epoch 29/50
# 14/14 - 4s - loss: 2.1459 - accuracy: 0.2114 - val_loss: 1.9825 - val_accuracy: 0.3400
# Epoch 30/50
# 14/14 - 4s - loss: 2.1016 - accuracy: 0.2886 - val_loss: 1.9625 - val_accuracy: 0.3400
# Epoch 31/50
# 14/14 - 4s - loss: 2.1243 - accuracy: 0.2400 - val_loss: 1.9454 - val_accuracy: 0.3800
# Epoch 32/50
# 14/14 - 4s - loss: 2.1463 - accuracy: 0.2486 - val_loss: 1.9314 - val_accuracy: 0.4000
# Epoch 33/50
# 14/14 - 4s - loss: 2.0743 - accuracy: 0.2486 - val_loss: 1.9110 - val_accuracy: 0.4000
# Epoch 34/50
# 14/14 - 4s - loss: 2.1079 - accuracy: 0.2486 - val_loss: 1.9001 - val_accuracy: 0.3800
# Epoch 35/50
# 14/14 - 4s - loss: 2.0970 - accuracy: 0.2857 - val_loss: 1.8808 - val_accuracy: 0.4000
# Epoch 36/50
# 14/14 - 4s - loss: 2.0935 - accuracy: 0.2771 - val_loss: 1.8627 - val_accuracy: 0.5000
# Epoch 37/50
# 14/14 - 4s - loss: 2.0891 - accuracy: 0.2657 - val_loss: 1.8419 - val_accuracy: 0.5200
# Epoch 38/50
# 14/14 - 4s - loss: 2.0775 - accuracy: 0.2486 - val_loss: 1.8233 - val_accuracy: 0.5400
# Epoch 39/50
# 14/14 - 4s - loss: 2.0569 - accuracy: 0.2800 - val_loss: 1.8029 - val_accuracy: 0.5400
# Epoch 40/50
# 14/14 - 4s - loss: 2.0222 - accuracy: 0.2886 - val_loss: 1.7883 - val_accuracy: 0.5400
# Epoch 41/50
# 14/14 - 4s - loss: 1.9871 - accuracy: 0.2943 - val_loss: 1.7685 - val_accuracy: 0.5800
# Epoch 42/50
# 14/14 - 4s - loss: 2.0509 - accuracy: 0.3286 - val_loss: 1.7510 - val_accuracy: 0.5800
# Epoch 43/50
# 14/14 - 4s - loss: 2.0332 - accuracy: 0.2971 - val_loss: 1.7300 - val_accuracy: 0.6000
# Epoch 44/50
# 14/14 - 4s - loss: 1.9749 - accuracy: 0.3229 - val_loss: 1.7144 - val_accuracy: 0.6200
# Epoch 45/50
# 14/14 - 4s - loss: 1.9691 - accuracy: 0.3400 - val_loss: 1.6898 - val_accuracy: 0.6200
# Epoch 46/50
# 14/14 - 4s - loss: 1.9603 - accuracy: 0.3229 - val_loss: 1.6703 - val_accuracy: 0.6200
# Epoch 47/50
# 14/14 - 4s - loss: 1.9543 - accuracy: 0.3571 - val_loss: 1.6457 - val_accuracy: 0.6200
# Epoch 48/50
# 14/14 - 4s - loss: 1.9101 - accuracy: 0.3571 - val_loss: 1.6267 - val_accuracy: 0.6400
# Epoch 49/50
# 14/14 - 4s - loss: 1.9183 - accuracy: 0.3457 - val_loss: 1.6019 - val_accuracy: 0.6400
# Epoch 50/50
# 14/14 - 4s - loss: 1.9233 - accuracy: 0.3429 - val_loss: 1.5771 - val_accuracy: 0.6400
# 100/100 [==============================] - 1s 7ms/step - loss: 1.7303 - accuracy: 0.5300
# Testing Accuracy : [1.7303184270858765, 0.5299999713897705]
# Fold No: 5
# Original Sizes: (350, 224, 224, 3) (50, 224, 224, 3) (100, 224, 224, 3) (350, 10) (50, 10) (100, 10)
# Epoch 1/50
# 14/14 - 4s - loss: 2.5904 - accuracy: 0.0771 - val_loss: 2.3454 - val_accuracy: 0.1400
# Epoch 2/50
# 14/14 - 4s - loss: 2.4613 - accuracy: 0.1257 - val_loss: 2.3051 - val_accuracy: 0.1400
# Epoch 3/50
# 14/14 - 4s - loss: 2.4175 - accuracy: 0.1400 - val_loss: 2.2844 - val_accuracy: 0.1200
# Epoch 4/50
# 14/14 - 4s - loss: 2.4653 - accuracy: 0.1114 - val_loss: 2.2653 - val_accuracy: 0.1600
# Epoch 5/50
# 14/14 - 4s - loss: 2.4497 - accuracy: 0.1286 - val_loss: 2.2522 - val_accuracy: 0.2200
# Epoch 6/50
# 14/14 - 4s - loss: 2.4173 - accuracy: 0.0943 - val_loss: 2.2363 - val_accuracy: 0.2400
# Epoch 7/50
# 14/14 - 4s - loss: 2.3609 - accuracy: 0.1457 - val_loss: 2.2247 - val_accuracy: 0.2200
# Epoch 8/50
# 14/14 - 4s - loss: 2.3229 - accuracy: 0.1229 - val_loss: 2.2136 - val_accuracy: 0.2600
# Epoch 9/50
# 14/14 - 4s - loss: 2.4317 - accuracy: 0.1057 - val_loss: 2.1977 - val_accuracy: 0.2400
# Epoch 10/50
# 14/14 - 4s - loss: 2.3549 - accuracy: 0.1143 - val_loss: 2.1870 - val_accuracy: 0.2400
# Epoch 11/50
# 14/14 - 4s - loss: 2.3349 - accuracy: 0.1600 - val_loss: 2.1775 - val_accuracy: 0.2800
# Epoch 12/50
# 14/14 - 4s - loss: 2.3281 - accuracy: 0.1343 - val_loss: 2.1636 - val_accuracy: 0.2400
# Epoch 13/50
# 14/14 - 4s - loss: 2.3454 - accuracy: 0.1200 - val_loss: 2.1512 - val_accuracy: 0.2400
# Epoch 14/50
# 14/14 - 4s - loss: 2.3362 - accuracy: 0.1343 - val_loss: 2.1418 - val_accuracy: 0.3200
# Epoch 15/50
# 14/14 - 4s - loss: 2.3156 - accuracy: 0.1714 - val_loss: 2.1378 - val_accuracy: 0.3200
# Epoch 16/50
# 14/14 - 4s - loss: 2.2755 - accuracy: 0.1629 - val_loss: 2.1284 - val_accuracy: 0.3200
# Epoch 17/50
# 14/14 - 4s - loss: 2.2551 - accuracy: 0.1629 - val_loss: 2.1155 - val_accuracy: 0.3000
# Epoch 18/50
# 14/14 - 4s - loss: 2.2134 - accuracy: 0.2114 - val_loss: 2.1066 - val_accuracy: 0.3400
# Epoch 19/50
# 14/14 - 4s - loss: 2.2653 - accuracy: 0.1657 - val_loss: 2.0953 - val_accuracy: 0.3600
# Epoch 20/50
# 14/14 - 4s - loss: 2.2894 - accuracy: 0.1400 - val_loss: 2.0804 - val_accuracy: 0.3800
# Epoch 21/50
# 14/14 - 4s - loss: 2.2184 - accuracy: 0.1600 - val_loss: 2.0698 - val_accuracy: 0.3800
# Epoch 22/50
# 14/14 - 4s - loss: 2.2470 - accuracy: 0.2057 - val_loss: 2.0605 - val_accuracy: 0.3800
# Epoch 23/50
# 14/14 - 4s - loss: 2.2888 - accuracy: 0.1743 - val_loss: 2.0480 - val_accuracy: 0.3600
# Epoch 24/50
# 14/14 - 4s - loss: 2.2089 - accuracy: 0.2257 - val_loss: 2.0345 - val_accuracy: 0.4000
# Epoch 25/50
# 14/14 - 4s - loss: 2.2386 - accuracy: 0.1714 - val_loss: 2.0190 - val_accuracy: 0.4200
# Epoch 26/50
# 14/14 - 4s - loss: 2.2261 - accuracy: 0.1771 - val_loss: 2.0089 - val_accuracy: 0.4400
# Epoch 27/50
# 14/14 - 4s - loss: 2.1872 - accuracy: 0.2143 - val_loss: 1.9997 - val_accuracy: 0.5000
# Epoch 28/50
# 14/14 - 4s - loss: 2.1809 - accuracy: 0.2171 - val_loss: 1.9861 - val_accuracy: 0.4400
# Epoch 29/50
# 14/14 - 4s - loss: 2.1651 - accuracy: 0.2286 - val_loss: 1.9761 - val_accuracy: 0.4600
# Epoch 30/50
# 14/14 - 4s - loss: 2.1521 - accuracy: 0.2429 - val_loss: 1.9630 - val_accuracy: 0.5600
# Epoch 31/50
# 14/14 - 4s - loss: 2.1411 - accuracy: 0.2571 - val_loss: 1.9480 - val_accuracy: 0.5600
# Epoch 32/50
# 14/14 - 4s - loss: 2.1683 - accuracy: 0.2286 - val_loss: 1.9302 - val_accuracy: 0.5800
# Epoch 33/50
# 14/14 - 4s - loss: 2.0925 - accuracy: 0.2229 - val_loss: 1.9135 - val_accuracy: 0.5800
# Epoch 34/50
# 14/14 - 4s - loss: 2.0579 - accuracy: 0.3171 - val_loss: 1.8977 - val_accuracy: 0.5800
# Epoch 35/50
# 14/14 - 4s - loss: 2.1186 - accuracy: 0.2257 - val_loss: 1.8824 - val_accuracy: 0.6200
# Epoch 36/50
# 14/14 - 4s - loss: 2.0716 - accuracy: 0.2857 - val_loss: 1.8626 - val_accuracy: 0.6400
# Epoch 37/50
# 14/14 - 4s - loss: 2.0700 - accuracy: 0.2886 - val_loss: 1.8446 - val_accuracy: 0.6600
# Epoch 38/50
# 14/14 - 4s - loss: 2.0371 - accuracy: 0.2943 - val_loss: 1.8261 - val_accuracy: 0.6400
# Epoch 39/50
# 14/14 - 4s - loss: 2.0380 - accuracy: 0.2686 - val_loss: 1.8090 - val_accuracy: 0.6600
# Epoch 40/50
# 14/14 - 4s - loss: 2.0727 - accuracy: 0.3229 - val_loss: 1.7906 - val_accuracy: 0.6800
# Epoch 41/50
# 14/14 - 4s - loss: 2.0338 - accuracy: 0.2943 - val_loss: 1.7752 - val_accuracy: 0.7000
# Epoch 42/50
# 14/14 - 4s - loss: 2.0020 - accuracy: 0.2886 - val_loss: 1.7546 - val_accuracy: 0.6800
# Epoch 43/50
# 14/14 - 4s - loss: 1.9840 - accuracy: 0.3029 - val_loss: 1.7283 - val_accuracy: 0.6800
# Epoch 44/50
# 14/14 - 4s - loss: 1.9645 - accuracy: 0.3600 - val_loss: 1.7024 - val_accuracy: 0.7000
# Epoch 45/50
# 14/14 - 4s - loss: 1.9727 - accuracy: 0.2886 - val_loss: 1.6827 - val_accuracy: 0.7000
# Epoch 46/50
# 14/14 - 4s - loss: 1.9753 - accuracy: 0.3343 - val_loss: 1.6662 - val_accuracy: 0.7200
# Epoch 47/50
# 14/14 - 4s - loss: 1.8842 - accuracy: 0.3800 - val_loss: 1.6442 - val_accuracy: 0.7200
# Epoch 48/50
# 14/14 - 4s - loss: 1.8882 - accuracy: 0.3457 - val_loss: 1.6145 - val_accuracy: 0.7200
# Epoch 49/50
# 14/14 - 4s - loss: 1.9130 - accuracy: 0.3543 - val_loss: 1.5934 - val_accuracy: 0.7200
# Epoch 50/50
# 14/14 - 4s - loss: 1.8291 - accuracy: 0.4543 - val_loss: 1.5656 - val_accuracy: 0.7600
# 100/100 [==============================] - 1s 7ms/step - loss: 1.6568 - accuracy: 0.6700
# Testing Accuracy : [1.6567665338516235, 0.6700000166893005]
# Fold No: 6
# Original Sizes: (350, 224, 224, 3) (50, 224, 224, 3) (100, 224, 224, 3) (350, 10) (50, 10) (100, 10)
# Epoch 1/50
# 14/14 - 5s - loss: 2.7105 - accuracy: 0.1257 - val_loss: 2.4572 - val_accuracy: 0.1600
# Epoch 2/50
# 14/14 - 4s - loss: 2.5628 - accuracy: 0.1229 - val_loss: 2.3619 - val_accuracy: 0.1600
# Epoch 3/50
# 14/14 - 4s - loss: 2.4990 - accuracy: 0.1229 - val_loss: 2.3115 - val_accuracy: 0.1200
# Epoch 4/50
# 14/14 - 4s - loss: 2.4268 - accuracy: 0.1114 - val_loss: 2.2779 - val_accuracy: 0.1600
# Epoch 5/50
# 14/14 - 4s - loss: 2.4251 - accuracy: 0.1171 - val_loss: 2.2610 - val_accuracy: 0.1600
# Epoch 6/50
# 14/14 - 4s - loss: 2.3716 - accuracy: 0.1457 - val_loss: 2.2444 - val_accuracy: 0.1600
# Epoch 7/50
# 14/14 - 4s - loss: 2.3949 - accuracy: 0.1171 - val_loss: 2.2308 - val_accuracy: 0.2000
# Epoch 8/50
# 14/14 - 4s - loss: 2.3467 - accuracy: 0.1229 - val_loss: 2.2222 - val_accuracy: 0.2200
# Epoch 9/50
# 14/14 - 4s - loss: 2.3582 - accuracy: 0.1200 - val_loss: 2.2150 - val_accuracy: 0.2200
# Epoch 10/50
# 14/14 - 4s - loss: 2.3296 - accuracy: 0.1200 - val_loss: 2.2097 - val_accuracy: 0.2200
# Epoch 11/50
# 14/14 - 4s - loss: 2.2993 - accuracy: 0.1600 - val_loss: 2.2060 - val_accuracy: 0.2600
# Epoch 12/50
# 14/14 - 4s - loss: 2.2828 - accuracy: 0.1371 - val_loss: 2.1964 - val_accuracy: 0.2800
# Epoch 13/50
# 14/14 - 4s - loss: 2.3105 - accuracy: 0.1343 - val_loss: 2.1882 - val_accuracy: 0.3000
# Epoch 14/50
# 14/14 - 4s - loss: 2.2919 - accuracy: 0.1514 - val_loss: 2.1800 - val_accuracy: 0.2800
# Epoch 15/50
# 14/14 - 4s - loss: 2.2790 - accuracy: 0.1457 - val_loss: 2.1731 - val_accuracy: 0.2800
# Epoch 16/50
# 14/14 - 4s - loss: 2.2591 - accuracy: 0.1971 - val_loss: 2.1654 - val_accuracy: 0.3200
# Epoch 17/50
# 14/14 - 4s - loss: 2.2966 - accuracy: 0.1629 - val_loss: 2.1554 - val_accuracy: 0.3200
# Epoch 18/50
# 14/14 - 4s - loss: 2.2132 - accuracy: 0.2371 - val_loss: 2.1459 - val_accuracy: 0.3200
# Epoch 19/50
# 14/14 - 4s - loss: 2.2839 - accuracy: 0.1371 - val_loss: 2.1403 - val_accuracy: 0.3800
# Epoch 20/50
# 14/14 - 4s - loss: 2.2658 - accuracy: 0.1629 - val_loss: 2.1346 - val_accuracy: 0.3400
# Epoch 21/50
# 14/14 - 4s - loss: 2.2403 - accuracy: 0.1600 - val_loss: 2.1287 - val_accuracy: 0.3600
# Epoch 22/50
# 14/14 - 4s - loss: 2.2569 - accuracy: 0.1857 - val_loss: 2.1186 - val_accuracy: 0.4000
# Epoch 23/50
# 14/14 - 4s - loss: 2.1665 - accuracy: 0.2143 - val_loss: 2.1120 - val_accuracy: 0.3800
# Epoch 24/50
# 14/14 - 4s - loss: 2.2144 - accuracy: 0.1743 - val_loss: 2.1091 - val_accuracy: 0.4000
# Epoch 25/50
# 14/14 - 4s - loss: 2.1642 - accuracy: 0.2000 - val_loss: 2.0989 - val_accuracy: 0.4000
# Epoch 26/50
# 14/14 - 4s - loss: 2.1786 - accuracy: 0.2000 - val_loss: 2.0868 - val_accuracy: 0.4200
# Epoch 27/50
# 14/14 - 4s - loss: 2.1621 - accuracy: 0.2400 - val_loss: 2.0759 - val_accuracy: 0.4000
# Epoch 28/50
# 14/14 - 4s - loss: 2.1563 - accuracy: 0.2314 - val_loss: 2.0665 - val_accuracy: 0.3800
# Epoch 29/50
# 14/14 - 4s - loss: 2.1442 - accuracy: 0.2343 - val_loss: 2.0569 - val_accuracy: 0.4000
# Epoch 30/50
# 14/14 - 4s - loss: 2.1638 - accuracy: 0.1943 - val_loss: 2.0480 - val_accuracy: 0.4200
# Epoch 31/50
# 14/14 - 4s - loss: 2.1390 - accuracy: 0.2257 - val_loss: 2.0377 - val_accuracy: 0.4200
# Epoch 32/50
# 14/14 - 4s - loss: 2.1375 - accuracy: 0.2371 - val_loss: 2.0264 - val_accuracy: 0.4600
# Epoch 33/50
# 14/14 - 4s - loss: 2.1504 - accuracy: 0.2057 - val_loss: 2.0174 - val_accuracy: 0.4400
# Epoch 34/50
# 14/14 - 4s - loss: 2.0977 - accuracy: 0.2343 - val_loss: 2.0042 - val_accuracy: 0.4400
# Epoch 35/50
# 14/14 - 4s - loss: 2.0780 - accuracy: 0.3143 - val_loss: 1.9932 - val_accuracy: 0.4800
# Epoch 36/50
# 14/14 - 4s - loss: 2.0733 - accuracy: 0.2686 - val_loss: 1.9845 - val_accuracy: 0.5000
# Epoch 37/50
# 14/14 - 4s - loss: 2.0576 - accuracy: 0.3029 - val_loss: 1.9721 - val_accuracy: 0.5400
# Epoch 38/50
# 14/14 - 4s - loss: 2.0697 - accuracy: 0.2486 - val_loss: 1.9580 - val_accuracy: 0.5600
# Epoch 39/50
# 14/14 - 4s - loss: 2.1071 - accuracy: 0.2514 - val_loss: 1.9471 - val_accuracy: 0.5800
# Epoch 40/50
# 14/14 - 4s - loss: 2.0469 - accuracy: 0.2743 - val_loss: 1.9343 - val_accuracy: 0.6000
# Epoch 41/50
# 14/14 - 4s - loss: 2.0424 - accuracy: 0.2829 - val_loss: 1.9193 - val_accuracy: 0.6000
# Epoch 42/50
# 14/14 - 4s - loss: 2.0372 - accuracy: 0.3086 - val_loss: 1.9053 - val_accuracy: 0.6000
# Epoch 43/50
# 14/14 - 4s - loss: 2.0404 - accuracy: 0.2629 - val_loss: 1.8896 - val_accuracy: 0.5800
# Epoch 44/50
# 14/14 - 4s - loss: 2.0226 - accuracy: 0.2914 - val_loss: 1.8763 - val_accuracy: 0.5800
# Epoch 45/50
# 14/14 - 4s - loss: 2.0334 - accuracy: 0.2800 - val_loss: 1.8589 - val_accuracy: 0.6000
# Epoch 46/50
# 14/14 - 4s - loss: 1.9371 - accuracy: 0.3171 - val_loss: 1.8367 - val_accuracy: 0.6200
# Epoch 47/50
# 14/14 - 4s - loss: 1.9939 - accuracy: 0.3086 - val_loss: 1.8199 - val_accuracy: 0.6200
# Epoch 48/50
# 14/14 - 4s - loss: 1.9878 - accuracy: 0.3314 - val_loss: 1.7982 - val_accuracy: 0.6000
# Epoch 49/50
# 14/14 - 4s - loss: 1.9732 - accuracy: 0.3229 - val_loss: 1.7793 - val_accuracy: 0.6200
# Epoch 50/50
# 14/14 - 4s - loss: 1.9268 - accuracy: 0.3543 - val_loss: 1.7549 - val_accuracy: 0.6200
# 100/100 [==============================] - 1s 7ms/step - loss: 1.7929 - accuracy: 0.5700
# Testing Accuracy : [1.7928656339645386, 0.5699999928474426]
# Fold No: 7
# Original Sizes: (350, 224, 224, 3) (50, 224, 224, 3) (100, 224, 224, 3) (350, 10) (50, 10) (100, 10)
# Epoch 1/50
# 14/14 - 4s - loss: 2.6297 - accuracy: 0.0971 - val_loss: 2.3745 - val_accuracy: 0.0400
# Epoch 2/50
# 14/14 - 4s - loss: 2.5202 - accuracy: 0.1086 - val_loss: 2.3255 - val_accuracy: 0.0600
# Epoch 3/50
# 14/14 - 4s - loss: 2.4918 - accuracy: 0.0971 - val_loss: 2.2912 - val_accuracy: 0.0800
# Epoch 4/50
# 14/14 - 4s - loss: 2.4537 - accuracy: 0.0914 - val_loss: 2.2750 - val_accuracy: 0.1000
# Epoch 5/50
# 14/14 - 4s - loss: 2.4668 - accuracy: 0.1000 - val_loss: 2.2625 - val_accuracy: 0.1200
# Epoch 6/50
# 14/14 - 4s - loss: 2.3895 - accuracy: 0.0943 - val_loss: 2.2445 - val_accuracy: 0.2200
# Epoch 7/50
# 14/14 - 4s - loss: 2.4083 - accuracy: 0.1029 - val_loss: 2.2313 - val_accuracy: 0.2600
# Epoch 8/50
# 14/14 - 4s - loss: 2.4180 - accuracy: 0.0943 - val_loss: 2.2178 - val_accuracy: 0.3000
# Epoch 9/50
# 14/14 - 4s - loss: 2.3557 - accuracy: 0.1400 - val_loss: 2.2102 - val_accuracy: 0.3000
# Epoch 10/50
# 14/14 - 4s - loss: 2.3022 - accuracy: 0.1400 - val_loss: 2.1957 - val_accuracy: 0.3200
# Epoch 11/50
# 14/14 - 4s - loss: 2.3284 - accuracy: 0.1429 - val_loss: 2.1851 - val_accuracy: 0.3800
# Epoch 12/50
# 14/14 - 4s - loss: 2.3483 - accuracy: 0.1229 - val_loss: 2.1765 - val_accuracy: 0.3600
# Epoch 13/50
# 14/14 - 4s - loss: 2.3218 - accuracy: 0.1171 - val_loss: 2.1661 - val_accuracy: 0.3400
# Epoch 14/50
# 14/14 - 4s - loss: 2.2707 - accuracy: 0.1600 - val_loss: 2.1561 - val_accuracy: 0.3800
# Epoch 15/50
# 14/14 - 4s - loss: 2.2596 - accuracy: 0.1657 - val_loss: 2.1477 - val_accuracy: 0.3800
# Epoch 16/50
# 14/14 - 4s - loss: 2.2885 - accuracy: 0.1457 - val_loss: 2.1400 - val_accuracy: 0.3600
# Epoch 17/50
# 14/14 - 4s - loss: 2.2635 - accuracy: 0.1343 - val_loss: 2.1281 - val_accuracy: 0.3400
# Epoch 18/50
# 14/14 - 4s - loss: 2.2396 - accuracy: 0.1800 - val_loss: 2.1131 - val_accuracy: 0.3600
# Epoch 19/50
# 14/14 - 4s - loss: 2.2665 - accuracy: 0.1886 - val_loss: 2.1034 - val_accuracy: 0.3800
# Epoch 20/50
# 14/14 - 4s - loss: 2.2708 - accuracy: 0.1543 - val_loss: 2.0926 - val_accuracy: 0.4000
# Epoch 21/50
# 14/14 - 4s - loss: 2.2709 - accuracy: 0.1514 - val_loss: 2.0757 - val_accuracy: 0.4400
# Epoch 22/50
# 14/14 - 4s - loss: 2.2166 - accuracy: 0.1914 - val_loss: 2.0647 - val_accuracy: 0.4200
# Epoch 23/50
# 14/14 - 4s - loss: 2.2321 - accuracy: 0.1857 - val_loss: 2.0575 - val_accuracy: 0.4400
# Epoch 24/50
# 14/14 - 4s - loss: 2.1946 - accuracy: 0.1943 - val_loss: 2.0481 - val_accuracy: 0.4400
# Epoch 25/50
# 14/14 - 4s - loss: 2.1785 - accuracy: 0.2086 - val_loss: 2.0356 - val_accuracy: 0.4800
# Epoch 26/50
# 14/14 - 4s - loss: 2.1862 - accuracy: 0.2057 - val_loss: 2.0275 - val_accuracy: 0.4800
# Epoch 27/50
# 14/14 - 4s - loss: 2.2183 - accuracy: 0.2000 - val_loss: 2.0177 - val_accuracy: 0.5200
# Epoch 28/50
# 14/14 - 4s - loss: 2.1970 - accuracy: 0.1857 - val_loss: 2.0054 - val_accuracy: 0.4800
# Epoch 29/50
# 14/14 - 4s - loss: 2.1779 - accuracy: 0.1914 - val_loss: 1.9943 - val_accuracy: 0.5000
# Epoch 30/50
# 14/14 - 4s - loss: 2.2050 - accuracy: 0.1629 - val_loss: 1.9819 - val_accuracy: 0.5000
# Epoch 31/50
# 14/14 - 4s - loss: 2.1751 - accuracy: 0.1971 - val_loss: 1.9703 - val_accuracy: 0.5600
# Epoch 32/50
# 14/14 - 4s - loss: 2.1134 - accuracy: 0.2543 - val_loss: 1.9560 - val_accuracy: 0.5800
# Epoch 33/50
# 14/14 - 4s - loss: 2.0990 - accuracy: 0.2600 - val_loss: 1.9414 - val_accuracy: 0.5800
# Epoch 34/50
# 14/14 - 4s - loss: 2.1000 - accuracy: 0.2286 - val_loss: 1.9313 - val_accuracy: 0.5600
# Epoch 35/50
# 14/14 - 4s - loss: 2.0917 - accuracy: 0.2486 - val_loss: 1.9122 - val_accuracy: 0.6000
# Epoch 36/50
# 14/14 - 4s - loss: 2.1185 - accuracy: 0.2514 - val_loss: 1.8971 - val_accuracy: 0.6000
# Epoch 37/50
# 14/14 - 4s - loss: 2.0562 - accuracy: 0.2857 - val_loss: 1.8748 - val_accuracy: 0.5800
# Epoch 38/50
# 14/14 - 4s - loss: 2.0705 - accuracy: 0.2629 - val_loss: 1.8500 - val_accuracy: 0.6000
# Epoch 39/50
# 14/14 - 4s - loss: 2.0599 - accuracy: 0.2657 - val_loss: 1.8362 - val_accuracy: 0.6000
# Epoch 40/50
# 14/14 - 4s - loss: 2.0859 - accuracy: 0.2429 - val_loss: 1.8184 - val_accuracy: 0.6000
# Epoch 41/50
# 14/14 - 4s - loss: 2.0763 - accuracy: 0.2486 - val_loss: 1.8054 - val_accuracy: 0.6000
# Epoch 42/50
# 14/14 - 4s - loss: 2.0197 - accuracy: 0.3086 - val_loss: 1.7914 - val_accuracy: 0.6000
# Epoch 43/50
# 14/14 - 4s - loss: 2.0224 - accuracy: 0.3029 - val_loss: 1.7738 - val_accuracy: 0.6200
# Epoch 44/50
# 14/14 - 4s - loss: 2.0058 - accuracy: 0.3200 - val_loss: 1.7545 - val_accuracy: 0.6000
# Epoch 45/50
# 14/14 - 4s - loss: 1.9996 - accuracy: 0.3057 - val_loss: 1.7278 - val_accuracy: 0.6400
# Epoch 46/50
# 14/14 - 4s - loss: 1.9558 - accuracy: 0.3343 - val_loss: 1.7026 - val_accuracy: 0.6800
# Epoch 47/50
# 14/14 - 4s - loss: 1.9424 - accuracy: 0.3514 - val_loss: 1.6727 - val_accuracy: 0.6800
# Epoch 48/50
# 14/14 - 4s - loss: 1.9274 - accuracy: 0.3286 - val_loss: 1.6518 - val_accuracy: 0.6800
# Epoch 49/50
# 14/14 - 4s - loss: 1.9172 - accuracy: 0.3200 - val_loss: 1.6311 - val_accuracy: 0.6800
# Epoch 50/50
# 14/14 - 4s - loss: 1.9096 - accuracy: 0.3257 - val_loss: 1.6090 - val_accuracy: 0.7000
# 100/100 [==============================] - 1s 7ms/step - loss: 1.7123 - accuracy: 0.6000
# Testing Accuracy : [1.7123217582702637, 0.6000000238418579]
# Fold No: 8
# Original Sizes: (350, 224, 224, 3) (50, 224, 224, 3) (100, 224, 224, 3) (350, 10) (50, 10) (100, 10)
# Epoch 1/50
# 14/14 - 4s - loss: 2.6850 - accuracy: 0.1114 - val_loss: 2.3565 - val_accuracy: 0.0800
# Epoch 2/50
# 14/14 - 4s - loss: 2.5108 - accuracy: 0.1229 - val_loss: 2.3094 - val_accuracy: 0.1000
# Epoch 3/50
# 14/14 - 4s - loss: 2.5019 - accuracy: 0.1143 - val_loss: 2.2825 - val_accuracy: 0.1000
# Epoch 4/50
# 14/14 - 4s - loss: 2.4811 - accuracy: 0.0829 - val_loss: 2.2726 - val_accuracy: 0.1000
# Epoch 5/50
# 14/14 - 4s - loss: 2.4545 - accuracy: 0.0971 - val_loss: 2.2566 - val_accuracy: 0.2000
# Epoch 6/50
# 14/14 - 4s - loss: 2.4102 - accuracy: 0.1371 - val_loss: 2.2481 - val_accuracy: 0.2200
# Epoch 7/50
# 14/14 - 4s - loss: 2.3983 - accuracy: 0.1229 - val_loss: 2.2397 - val_accuracy: 0.2600
# Epoch 8/50
# 14/14 - 4s - loss: 2.3787 - accuracy: 0.1257 - val_loss: 2.2263 - val_accuracy: 0.2800
# Epoch 9/50
# 14/14 - 4s - loss: 2.3271 - accuracy: 0.1143 - val_loss: 2.2093 - val_accuracy: 0.3000
# Epoch 10/50
# 14/14 - 4s - loss: 2.3297 - accuracy: 0.1143 - val_loss: 2.1978 - val_accuracy: 0.3000
# Epoch 11/50
# 14/14 - 4s - loss: 2.3493 - accuracy: 0.1286 - val_loss: 2.1836 - val_accuracy: 0.3200
# Epoch 12/50
# 14/14 - 4s - loss: 2.3276 - accuracy: 0.1200 - val_loss: 2.1745 - val_accuracy: 0.3400
# Epoch 13/50
# 14/14 - 4s - loss: 2.3063 - accuracy: 0.1714 - val_loss: 2.1613 - val_accuracy: 0.3400
# Epoch 14/50
# 14/14 - 4s - loss: 2.3089 - accuracy: 0.1286 - val_loss: 2.1533 - val_accuracy: 0.3400
# Epoch 15/50
# 14/14 - 4s - loss: 2.3231 - accuracy: 0.1457 - val_loss: 2.1450 - val_accuracy: 0.3200
# Epoch 16/50
# 14/14 - 4s - loss: 2.3218 - accuracy: 0.1343 - val_loss: 2.1356 - val_accuracy: 0.3400
# Epoch 17/50
# 14/14 - 4s - loss: 2.3153 - accuracy: 0.1486 - val_loss: 2.1195 - val_accuracy: 0.4200
# Epoch 18/50
# 14/14 - 4s - loss: 2.2808 - accuracy: 0.1400 - val_loss: 2.1098 - val_accuracy: 0.4000
# Epoch 19/50
# 14/14 - 4s - loss: 2.3045 - accuracy: 0.1200 - val_loss: 2.1001 - val_accuracy: 0.4000
# Epoch 20/50
# 14/14 - 4s - loss: 2.2048 - accuracy: 0.1629 - val_loss: 2.0873 - val_accuracy: 0.4400
# Epoch 21/50
# 14/14 - 4s - loss: 2.1985 - accuracy: 0.2000 - val_loss: 2.0729 - val_accuracy: 0.4200
# Epoch 22/50
# 14/14 - 4s - loss: 2.2541 - accuracy: 0.1629 - val_loss: 2.0611 - val_accuracy: 0.4000
# Epoch 23/50
# 14/14 - 4s - loss: 2.2767 - accuracy: 0.1343 - val_loss: 2.0502 - val_accuracy: 0.4000
# Epoch 24/50
# 14/14 - 4s - loss: 2.2249 - accuracy: 0.1743 - val_loss: 2.0337 - val_accuracy: 0.4200
# Epoch 25/50
# 14/14 - 4s - loss: 2.1904 - accuracy: 0.2143 - val_loss: 2.0261 - val_accuracy: 0.4600
# Epoch 26/50
# 14/14 - 4s - loss: 2.2078 - accuracy: 0.1657 - val_loss: 2.0105 - val_accuracy: 0.4800
# Epoch 27/50
# 14/14 - 4s - loss: 2.1871 - accuracy: 0.2200 - val_loss: 2.0010 - val_accuracy: 0.5000
# Epoch 28/50
# 14/14 - 4s - loss: 2.2039 - accuracy: 0.2257 - val_loss: 1.9905 - val_accuracy: 0.5200
# Epoch 29/50
# 14/14 - 4s - loss: 2.2038 - accuracy: 0.1857 - val_loss: 1.9831 - val_accuracy: 0.5400
# Epoch 30/50
# 14/14 - 4s - loss: 2.1332 - accuracy: 0.2000 - val_loss: 1.9662 - val_accuracy: 0.5800
# Epoch 31/50
# 14/14 - 4s - loss: 2.1404 - accuracy: 0.1971 - val_loss: 1.9532 - val_accuracy: 0.5800
# Epoch 32/50
# 14/14 - 4s - loss: 2.1375 - accuracy: 0.2057 - val_loss: 1.9437 - val_accuracy: 0.5800
# Epoch 33/50
# 14/14 - 4s - loss: 2.1423 - accuracy: 0.2114 - val_loss: 1.9295 - val_accuracy: 0.5800
# Epoch 34/50
# 14/14 - 4s - loss: 2.1249 - accuracy: 0.2429 - val_loss: 1.9109 - val_accuracy: 0.5800
# Epoch 35/50
# 14/14 - 4s - loss: 2.1416 - accuracy: 0.2343 - val_loss: 1.8960 - val_accuracy: 0.5800
# Epoch 36/50
# 14/14 - 4s - loss: 2.1005 - accuracy: 0.3000 - val_loss: 1.8799 - val_accuracy: 0.6000
# Epoch 37/50
# 14/14 - 4s - loss: 2.1147 - accuracy: 0.2314 - val_loss: 1.8616 - val_accuracy: 0.6000
# Epoch 38/50
# 14/14 - 4s - loss: 2.0757 - accuracy: 0.2686 - val_loss: 1.8422 - val_accuracy: 0.6200
# Epoch 39/50
# 14/14 - 4s - loss: 2.0912 - accuracy: 0.2514 - val_loss: 1.8302 - val_accuracy: 0.6200
# Epoch 40/50
# 14/14 - 4s - loss: 2.0831 - accuracy: 0.2771 - val_loss: 1.8084 - val_accuracy: 0.6600
# Epoch 41/50
# 14/14 - 4s - loss: 2.0270 - accuracy: 0.2743 - val_loss: 1.7920 - val_accuracy: 0.6600
# Epoch 42/50
# 14/14 - 4s - loss: 2.0663 - accuracy: 0.2800 - val_loss: 1.7719 - val_accuracy: 0.6600
# Epoch 43/50
# 14/14 - 4s - loss: 2.0388 - accuracy: 0.2943 - val_loss: 1.7525 - val_accuracy: 0.6600
# Epoch 44/50
# 14/14 - 4s - loss: 2.0241 - accuracy: 0.2714 - val_loss: 1.7386 - val_accuracy: 0.6600
# Epoch 45/50
# 14/14 - 4s - loss: 1.9820 - accuracy: 0.3371 - val_loss: 1.7171 - val_accuracy: 0.6800
# Epoch 46/50
# 14/14 - 4s - loss: 2.0220 - accuracy: 0.3143 - val_loss: 1.6983 - val_accuracy: 0.6600
# Epoch 47/50
# 14/14 - 4s - loss: 1.9968 - accuracy: 0.3171 - val_loss: 1.6767 - val_accuracy: 0.6800
# Epoch 48/50
# 14/14 - 4s - loss: 1.9505 - accuracy: 0.3800 - val_loss: 1.6550 - val_accuracy: 0.7200
# Epoch 49/50
# 14/14 - 4s - loss: 1.9187 - accuracy: 0.3943 - val_loss: 1.6301 - val_accuracy: 0.7200
# Epoch 50/50
# 14/14 - 4s - loss: 1.9267 - accuracy: 0.3629 - val_loss: 1.6034 - val_accuracy: 0.7400
# 100/100 [==============================] - 1s 7ms/step - loss: 1.6994 - accuracy: 0.6000
# Testing Accuracy : [1.6994436979293823, 0.6000000238418579]
# [63.999998569488525, 62.00000047683716, 62.99999952316284, 52.99999713897705, 67.00000166893005, 56.99999928474426, 60.00000238418579, 60.00000238418579]
# Average Accuracy: : 60.75%
# Standard Deviation: +/-: 4.05%
# Total time taken 1507.7780892848969
