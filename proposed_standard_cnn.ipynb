# %% [markdown]
# <a href="https://colab.research.google.com/github/vijayakanth/Transfer-Learning/blob/main/proposed_standard_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
    from google.colab import drive
    drive.mount("/content/drive", force_remount=False)
# Out:
# Mounted at /content/drive

# %%
# ====== SETUP ======
import os, glob, time, random
import numpy as np
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv2D, Dense, Activation, Dropout,
                                     BatchNormalization, DepthwiseConv2D,
                                     GlobalAveragePooling2D, Multiply, Reshape)
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# Reproducibility
SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# ====== PATHS ======
DATA_DIR = "/content/drive/MyDrive/ColabNotebooks/data/SriLankan_TeaLeaf_5968"
SAVE_DIR = "/content/drive/MyDrive/ColabNotebooks/outputs"
os.makedirs(SAVE_DIR, exist_ok=True)

# ====== DATA LOADER ======
def getImages(data_dir=DATA_DIR, no_of_classes=6, target_size=(224, 224)):
    images, labels = [], []
    class_dirs = sorted([d for d in glob.glob(os.path.join(data_dir, "*")) if os.path.isdir(d)])
    class_dirs = class_dirs[:no_of_classes]

    for cls_path in class_dirs:
        label = os.path.basename(cls_path)
        for img_path in glob.glob(os.path.join(cls_path, "*.jpg")):
            img = cv2.imread(img_path)
            if img is None:
                continue
            img = cv2.resize(img, target_size, interpolation=cv2.INTER_AREA)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            images.append(img)
            labels.append(label)

    images = np.array(images, dtype=np.uint8)
    labels = np.array(labels)
    unique_labels = np.unique(labels)
    label_to_id = {lab: i for i, lab in enumerate(unique_labels)}
    id_to_label = {i: lab for lab, i in label_to_id.items()}
    label_ids = np.array([label_to_id[x] for x in labels], dtype=np.int64)

    print(f"Total Dataset: {images.shape[0]} images across {len(unique_labels)} classes.")
    return images, label_ids, id_to_label

# Load Data
disease_imgs, disease_labels, id_to_label = getImages()
numClasses = len(id_to_label)

# ====== SPLIT DATA (Train 70%, Val 10%, Test 20%) ======
# Split: 70% train, 30% temp
X_train, X_temp, y_train_idx, y_temp_idx = train_test_split(
    disease_imgs, disease_labels, test_size=0.3, random_state=SEED, stratify=disease_labels
)

# Split temp into: 10% val, 20% test  →  test_size=0.667 of the 30%
X_val, X_test, y_val_idx, y_test_idx = train_test_split(
    X_temp, y_temp_idx, test_size=0.667, random_state=SEED, stratify=y_temp_idx
)

# Convert to Categorical
Y_train = to_categorical(y_train_idx, numClasses)
Y_val   = to_categorical(y_val_idx,   numClasses)
Y_test  = to_categorical(y_test_idx,  numClasses)

# Calculate Class Weights
weights = compute_class_weight('balanced', classes=np.unique(y_train_idx), y=y_train_idx)
class_weight_dict = dict(enumerate(weights))

# ====== AUGMENTATION ======
train_datagen    = ImageDataGenerator(
    rescale=1./255
)
val_test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow(X_train, Y_train, batch_size=32, shuffle=True)
val_gen   = val_test_datagen.flow(X_val,   Y_val,   batch_size=32, shuffle=False)

# ====== STANDARD CNN MODEL ======
def build_tea_mobile_v2(input_shape=(224, 224, 3), num_classes=6):
    inputs = Input(shape=input_shape)

    # Block 1
    x = Conv2D(32, (3, 3), padding='same', use_bias=False)(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(32, (3, 3), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = tf.keras.layers.MaxPooling2D((2, 2))(x)

    # Block 2
    x = Conv2D(64, (3, 3), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(128, (3, 3), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = tf.keras.layers.MaxPooling2D((2, 2))(x)

    # Block 3
    x = Conv2D(128, (3, 3), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = tf.keras.layers.MaxPooling2D((2, 2))(x)



    # Classifier Head
    x = GlobalAveragePooling2D()(x)
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer=AdamW(3e-4),
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.02),
        metrics=['accuracy']
    )
    return model

model = build_tea_mobile_v2(num_classes=numClasses)
model.summary()

# ====== TRAINING ======
callbacks = [
    EarlyStopping(monitor='val_loss', patience=12, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, verbose=0),  # FIX 3: verbose=0
    ModelCheckpoint(os.path.join(SAVE_DIR, "best_tea_model.keras"),
                    monitor='val_accuracy', save_best_only=True)
]

print("\nStarting Training with Class Weights...")
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=50,
    class_weight=class_weight_dict,
    callbacks=callbacks,
    verbose=1
)

# ====== FINAL EVALUATION ======
# FIX 4: predict directly on normalized array — avoids generator step/batch misalignment
X_test_norm = X_test.astype(np.float32) / 255.0
y_pred_probs = model.predict(X_test_norm, batch_size=32)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = y_test_idx

test_loss, test_acc = model.evaluate(X_test_norm, Y_test, batch_size=32, verbose=0)
print(f"\nTest Loss: {test_loss:.4f} | Test Accuracy: {test_acc * 100:.2f}%")

# FIX 5: sort id_to_label by key to guarantee correct label order
target_names = [id_to_label[i] for i in sorted(id_to_label.keys())]

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=target_names))

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens',
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Tea Leaf Disease Confusion Matrix')
plt.tight_layout()
plt.savefig(os.path.join(SAVE_DIR, "final_cm.png"))
plt.show()

# Save as TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open(os.path.join(SAVE_DIR, "tea_model.tflite"), "wb") as f:
    f.write(tflite_model)
print("\nModel saved as TFLite.")
# Out:
# Total Dataset: 5968 images across 6 classes.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 224, 224, 32)   │         9,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 112, 112, 64)   │        18,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 112, 112, 128)  │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 112, 112, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 112, 112, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 56, 56, 128)    │       147,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 56, 56, 256)    │       294,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 56, 56, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 56, 56, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 564,006 (2.15 MB)
#  Trainable params: 562,726 (2.15 MB)
#  Non-trainable params: 1,280 (5.00 KB)
# Starting Training with Class Weights...
# Epoch 1/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 68s 339ms/step - accuracy: 0.5511 - loss: 1.1582 - val_accuracy: 0.2081 - val_loss: 1.9125 - learning_rate: 3.0000e-04
# Epoch 2/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 194ms/step - accuracy: 0.6581 - loss: 0.9254 - val_accuracy: 0.2332 - val_loss: 4.0846 - learning_rate: 3.0000e-04
# Epoch 3/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 27s 208ms/step - accuracy: 0.6780 - loss: 0.8628 - val_accuracy: 0.2349 - val_loss: 3.8312 - learning_rate: 3.0000e-04
# Epoch 4/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 27s 207ms/step - accuracy: 0.7007 - loss: 0.8180 - val_accuracy: 0.4211 - val_loss: 2.4772 - learning_rate: 3.0000e-04
# Epoch 5/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 202ms/step - accuracy: 0.7304 - loss: 0.7684 - val_accuracy: 0.7416 - val_loss: 0.7940 - learning_rate: 3.0000e-04
# Epoch 6/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 201ms/step - accuracy: 0.7527 - loss: 0.7342 - val_accuracy: 0.6913 - val_loss: 1.0380 - learning_rate: 3.0000e-04
# Epoch 7/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 27s 203ms/step - accuracy: 0.7687 - loss: 0.6845 - val_accuracy: 0.6342 - val_loss: 0.9840 - learning_rate: 3.0000e-04
# Epoch 8/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 201ms/step - accuracy: 0.7802 - loss: 0.6516 - val_accuracy: 0.5487 - val_loss: 1.2819 - learning_rate: 3.0000e-04
# Epoch 9/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 201ms/step - accuracy: 0.7900 - loss: 0.6441 - val_accuracy: 0.7131 - val_loss: 0.8070 - learning_rate: 3.0000e-04
# Epoch 10/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 27s 203ms/step - accuracy: 0.8238 - loss: 0.5647 - val_accuracy: 0.7953 - val_loss: 0.6287 - learning_rate: 1.5000e-04
# Epoch 11/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 201ms/step - accuracy: 0.8425 - loss: 0.5291 - val_accuracy: 0.6007 - val_loss: 1.0847 - learning_rate: 1.5000e-04
# Epoch 12/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 202ms/step - accuracy: 0.8453 - loss: 0.5264 - val_accuracy: 0.7869 - val_loss: 0.6847 - learning_rate: 1.5000e-04
# Epoch 13/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 27s 203ms/step - accuracy: 0.8473 - loss: 0.5213 - val_accuracy: 0.6930 - val_loss: 0.9378 - learning_rate: 1.5000e-04
# Epoch 14/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 27s 202ms/step - accuracy: 0.8602 - loss: 0.4848 - val_accuracy: 0.8054 - val_loss: 0.6359 - learning_rate: 1.5000e-04
# Epoch 15/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 202ms/step - accuracy: 0.8724 - loss: 0.4584 - val_accuracy: 0.8742 - val_loss: 0.4843 - learning_rate: 7.5000e-05
# Epoch 16/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 201ms/step - accuracy: 0.8880 - loss: 0.4218 - val_accuracy: 0.8674 - val_loss: 0.4861 - learning_rate: 7.5000e-05
# Epoch 17/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 201ms/step - accuracy: 0.8980 - loss: 0.4131 - val_accuracy: 0.8557 - val_loss: 0.4920 - learning_rate: 7.5000e-05
# Epoch 18/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 201ms/step - accuracy: 0.8911 - loss: 0.4175 - val_accuracy: 0.8725 - val_loss: 0.4633 - learning_rate: 7.5000e-05
# Epoch 19/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 202ms/step - accuracy: 0.8920 - loss: 0.4186 - val_accuracy: 0.8691 - val_loss: 0.4767 - learning_rate: 7.5000e-05
# Epoch 20/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 27s 203ms/step - accuracy: 0.8942 - loss: 0.4007 - val_accuracy: 0.8624 - val_loss: 0.4897 - learning_rate: 7.5000e-05
# Epoch 21/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 27s 203ms/step - accuracy: 0.9052 - loss: 0.3893 - val_accuracy: 0.8993 - val_loss: 0.4017 - learning_rate: 7.5000e-05
# Epoch 22/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 201ms/step - accuracy: 0.9059 - loss: 0.3804 - val_accuracy: 0.8993 - val_loss: 0.4079 - learning_rate: 7.5000e-05
# Epoch 23/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 27s 202ms/step - accuracy: 0.9176 - loss: 0.3698 - val_accuracy: 0.8826 - val_loss: 0.4172 - learning_rate: 7.5000e-05
# Epoch 24/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 202ms/step - accuracy: 0.9078 - loss: 0.3666 - val_accuracy: 0.8943 - val_loss: 0.4128 - learning_rate: 7.5000e-05
# Epoch 25/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 201ms/step - accuracy: 0.9066 - loss: 0.3709 - val_accuracy: 0.8893 - val_loss: 0.4106 - learning_rate: 7.5000e-05
# Epoch 26/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 27s 203ms/step - accuracy: 0.9208 - loss: 0.3462 - val_accuracy: 0.9027 - val_loss: 0.3794 - learning_rate: 3.7500e-05
# Epoch 27/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 27s 203ms/step - accuracy: 0.9277 - loss: 0.3346 - val_accuracy: 0.9262 - val_loss: 0.3424 - learning_rate: 3.7500e-05
# Epoch 28/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 201ms/step - accuracy: 0.9308 - loss: 0.3270 - val_accuracy: 0.9195 - val_loss: 0.3370 - learning_rate: 3.7500e-05
# Epoch 29/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 201ms/step - accuracy: 0.9325 - loss: 0.3242 - val_accuracy: 0.9060 - val_loss: 0.3932 - learning_rate: 3.7500e-05
# Epoch 30/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 201ms/step - accuracy: 0.9375 - loss: 0.3168 - val_accuracy: 0.9060 - val_loss: 0.3731 - learning_rate: 3.7500e-05
# Epoch 31/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 201ms/step - accuracy: 0.9342 - loss: 0.3141 - val_accuracy: 0.9245 - val_loss: 0.3348 - learning_rate: 3.7500e-05
# Epoch 32/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 27s 202ms/step - accuracy: 0.9330 - loss: 0.3176 - val_accuracy: 0.9161 - val_loss: 0.3558 - learning_rate: 3.7500e-05
# Epoch 33/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 202ms/step - accuracy: 0.9380 - loss: 0.3064 - val_accuracy: 0.9111 - val_loss: 0.3861 - learning_rate: 3.7500e-05
# Epoch 34/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 202ms/step - accuracy: 0.9351 - loss: 0.3129 - val_accuracy: 0.9128 - val_loss: 0.3504 - learning_rate: 3.7500e-05
# Epoch 35/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 27s 203ms/step - accuracy: 0.9397 - loss: 0.3018 - val_accuracy: 0.9295 - val_loss: 0.3349 - learning_rate: 3.7500e-05
# Epoch 36/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 201ms/step - accuracy: 0.9425 - loss: 0.2945 - val_accuracy: 0.9279 - val_loss: 0.3250 - learning_rate: 1.8750e-05
# Epoch 37/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 201ms/step - accuracy: 0.9454 - loss: 0.2872 - val_accuracy: 0.9295 - val_loss: 0.3118 - learning_rate: 1.8750e-05
# Epoch 38/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 201ms/step - accuracy: 0.9445 - loss: 0.2884 - val_accuracy: 0.9211 - val_loss: 0.3279 - learning_rate: 1.8750e-05
# Epoch 39/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 27s 202ms/step - accuracy: 0.9526 - loss: 0.2721 - val_accuracy: 0.9262 - val_loss: 0.3172 - learning_rate: 1.8750e-05
# Epoch 40/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 27s 203ms/step - accuracy: 0.9459 - loss: 0.2887 - val_accuracy: 0.9362 - val_loss: 0.3021 - learning_rate: 1.8750e-05
# Epoch 41/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 27s 203ms/step - accuracy: 0.9452 - loss: 0.2874 - val_accuracy: 0.9346 - val_loss: 0.3026 - learning_rate: 1.8750e-05
# Epoch 42/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 202ms/step - accuracy: 0.9543 - loss: 0.2713 - val_accuracy: 0.9329 - val_loss: 0.2962 - learning_rate: 1.8750e-05
# Epoch 43/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 27s 203ms/step - accuracy: 0.9457 - loss: 0.2859 - val_accuracy: 0.9379 - val_loss: 0.2997 - learning_rate: 1.8750e-05
# Epoch 44/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 201ms/step - accuracy: 0.9495 - loss: 0.2820 - val_accuracy: 0.9279 - val_loss: 0.3034 - learning_rate: 1.8750e-05
# Epoch 45/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 27s 203ms/step - accuracy: 0.9480 - loss: 0.2784 - val_accuracy: 0.9362 - val_loss: 0.2976 - learning_rate: 1.8750e-05
# Epoch 46/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 201ms/step - accuracy: 0.9514 - loss: 0.2719 - val_accuracy: 0.9329 - val_loss: 0.3001 - learning_rate: 1.8750e-05
# Epoch 47/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 27s 202ms/step - accuracy: 0.9555 - loss: 0.2725 - val_accuracy: 0.9379 - val_loss: 0.2874 - learning_rate: 9.3750e-06
# Epoch 48/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 27s 203ms/step - accuracy: 0.9607 - loss: 0.2588 - val_accuracy: 0.9396 - val_loss: 0.2908 - learning_rate: 9.3750e-06
# Epoch 49/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 201ms/step - accuracy: 0.9548 - loss: 0.2654 - val_accuracy: 0.9346 - val_loss: 0.2934 - learning_rate: 9.3750e-06
# Epoch 50/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 202ms/step - accuracy: 0.9593 - loss: 0.2637 - val_accuracy: 0.9379 - val_loss: 0.2894 - learning_rate: 9.3750e-06
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step
#
# Test Loss: 0.2577 | Test Accuracy: 94.90%
#
# Classification Report:
#                  precision    recall  f1-score   support
#
# Algal_leaf_spot       0.96      0.95      0.95       248
#    Black_blight       0.95      0.92      0.94       194
#  Blister_blight       0.95      0.97      0.96       151
#     Gray_blight       0.94      0.91      0.93       250
#         Healthy       0.94      0.97      0.96       195
#    Spider_mites       0.96      0.99      0.97       157
#
#        accuracy                           0.95      1195
#       macro avg       0.95      0.95      0.95      1195
#    weighted avg       0.95      0.95      0.95      1195
# Saved artifact at '/tmp/tmps0_jb3tp'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 6), dtype=tf.float32, name=None)
# Captures:
#   135731843344592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731843345168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731843347856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731843347472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731843346320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731843348048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731843346512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731843348624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731843348240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731843346128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731843347280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731843349200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731843349392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731843350352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731843349584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731837551248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731837552592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731837552400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731837552016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731837553168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731837550864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731837554320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731837554512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731837553744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731837551824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731837553360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731837552976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731837552784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731837553936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731837555472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731837554896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731837554128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731837555088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135731837556432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#
# Model saved as TFLite.
